# %%
# Import dependencies
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import Citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": current_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | clyde river
# Processing Record 3 of Set 1 | concarneau
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | forio
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | gornyy
# Processing Record 10 of Set 1 | sedhiou
# Processing Record 11 of Set 1 | barcelos
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | fortuna
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 1 | krasnooktyabrskiy
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | eganville
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | port keats
# Processing Record 22 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 1 | rock sound
# Processing Record 24 of Set 1 | senges
# Processing Record 25 of Set 1 | gawler
# Processing Record 26 of Set 1 | halifax
# Processing Record 27 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 1 | babati
# Processing Record 29 of Set 1 | vestmannaeyjar
# Processing Record 30 of Set 1 | nyurba
# Processing Record 31 of Set 1 | bhopal
# Processing Record 32 of Set 1 | fairbanks
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | airai
# Processing Record 37 of Set 1 | koforidua
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | marsh harbour
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | kanungu
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | korla
# Processing Record 47 of Set 1 | sovetskiy
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | antofagasta
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | shubarkuduk
# Processing Record 2 of Set 2 | sobolevo
# Processing Record 3 of Set 2 | bay roberts
# Processing Record 4 of Set 2 | ilinskiy
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | hofn
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | te anau
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | teeli
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | dunedin
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | kubachi
# Processing Record 17 of Set 2 | bathsheba
# Processing Record 18 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | sibolga
# Processing Record 24 of Set 2 | carballo
# Processing Record 25 of Set 2 | vardo
# Processing Record 26 of Set 2 | sao jose da coroa grande
# Processing Record 27 of Set 2 | barra patuca
# Processing Record 28 of Set 2 | saveh
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | bowen
# Processing Record 34 of Set 2 | provideniya
# Processing Record 35 of Set 2 | black river
# Processing Record 36 of Set 2 | itarema
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | camacha
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | washougal
# Processing Record 44 of Set 2 | swift current
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | nome
# Processing Record 47 of Set 2 | saint-francois
# Processing Record 48 of Set 2 | maamba
# Processing Record 49 of Set 2 | rincon
# Processing Record 50 of Set 2 | portland
# Processing Record 1 of Set 3 | vila velha
# Processing Record 2 of Set 3 | tarakan
# Processing Record 3 of Set 3 | mackay
# Processing Record 4 of Set 3 | mahibadhoo
# Processing Record 5 of Set 3 | husavik
# Processing Record 6 of Set 3 | chenghai
# Processing Record 7 of Set 3 | bitung
# Processing Record 8 of Set 3 | vila franca do campo
# Processing Record 9 of Set 3 | kamenka
# Processing Record 10 of Set 3 | nouadhibou
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | ust-omchug
# Processing Record 13 of Set 3 | saint-augustin
# Processing Record 14 of Set 3 | san cristobal
# Processing Record 15 of Set 3 | sabang
# Processing Record 16 of Set 3 | pak phanang
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | bongandanga
# Processing Record 19 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | georgiyevskoye
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | jurm
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | miramar
# Processing Record 27 of Set 3 | veraval
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | gazanjyk
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | altay
# Processing Record 33 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 3 | machachi
# Processing Record 35 of Set 3 | sioux lookout
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | tromso
# Processing Record 38 of Set 3 | raga
# Processing Record 39 of Set 3 | komatipoort
# Processing Record 40 of Set 3 | juneau
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | tombouctou
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | hovd
# Processing Record 46 of Set 3 | xingyi
# Processing Record 47 of Set 3 | maceio
# Processing Record 48 of Set 3 | sincelejo
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | maarianhamina
# Processing Record 1 of Set 4 | kununurra
# Processing Record 2 of Set 4 | shimoda
# Processing Record 3 of Set 4 | hualmay
# Processing Record 4 of Set 4 | maridi
# Processing Record 5 of Set 4 | port hardy
# Processing Record 6 of Set 4 | isetskoye
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | baruun-urt
# Processing Record 10 of Set 4 | surami
# Processing Record 11 of Set 4 | ugoofaaru
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | narsaq
# Processing Record 15 of Set 4 | sao filipe
# Processing Record 16 of Set 4 | marau
# Processing Record 17 of Set 4 | margherita
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 4 | laguna
# Processing Record 21 of Set 4 | whitecourt
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | piney green
# Processing Record 24 of Set 4 | pingzhuang
# Processing Record 25 of Set 4 | bilibino
# Processing Record 26 of Set 4 | coquimbo
# Processing Record 27 of Set 4 | auki
# Processing Record 28 of Set 4 | gizo
# Processing Record 29 of Set 4 | zafarwal
# Processing Record 30 of Set 4 | bubaque
# Processing Record 31 of Set 4 | plouzane
# Processing Record 32 of Set 4 | victoria
# Processing Record 33 of Set 4 | poum
# Processing Record 34 of Set 4 | miracema do tocantins
# Processing Record 35 of Set 4 | puerto narino
# Processing Record 36 of Set 4 | chuy
# Processing Record 37 of Set 4 | ouallam
# Processing Record 38 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 4 | qaanaaq
# Processing Record 40 of Set 4 | saskylakh
# Processing Record 41 of Set 4 | tungor
# Processing Record 42 of Set 4 | padang
# Processing Record 43 of Set 4 | akyab
# Processing Record 44 of Set 4 | nyaunglebin
# Processing Record 45 of Set 4 | inirida
# Processing Record 46 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 4 | paita
# Processing Record 48 of Set 4 | riyadh
# Processing Record 49 of Set 4 | khatanga
# Processing Record 50 of Set 4 | seminole
# Processing Record 1 of Set 5 | erdenet
# Processing Record 2 of Set 5 | pevek
# Processing Record 3 of Set 5 | tezu
# Processing Record 4 of Set 5 | daru
# Processing Record 5 of Set 5 | naze
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | yulara
# Processing Record 8 of Set 5 | matara
# Processing Record 9 of Set 5 | bluefield
# Processing Record 10 of Set 5 | zhezkazgan
# Processing Record 11 of Set 5 | gidole
# Processing Record 12 of Set 5 | fort nelson
# Processing Record 13 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 14 of Set 5 | mahebourg
# Processing Record 15 of Set 5 | ust-ilimsk
# Processing Record 16 of Set 5 | kvitok
# Processing Record 17 of Set 5 | molteno
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | haizhou
# Processing Record 20 of Set 5 | amga
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | lompoc
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | platanos
# Processing Record 25 of Set 5 | bilma
# Processing Record 26 of Set 5 | solnechnyy
# Processing Record 27 of Set 5 | tolaga bay
# Processing Record 28 of Set 5 | adrar
# Processing Record 29 of Set 5 | severo-kurilsk
# Processing Record 30 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 5 | buala
# Processing Record 33 of Set 5 | kodiak
# Processing Record 34 of Set 5 | winslow
# Processing Record 35 of Set 5 | pisco
# Processing Record 36 of Set 5 | koshurnikovo
# Processing Record 37 of Set 5 | northam
# Processing Record 38 of Set 5 | diego de almagro
# Processing Record 39 of Set 5 | ahuimanu
# Processing Record 40 of Set 5 | putla
# City not found. Skipping...
# Processing Record 41 of Set 5 | darovskoy
# Processing Record 42 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 5 | westport
# Processing Record 44 of Set 5 | pacific grove
# Processing Record 45 of Set 5 | caravelas
# Processing Record 46 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 5 | ostrovnoy
# Processing Record 48 of Set 5 | newport
# Processing Record 49 of Set 5 | stara vyzhivka
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | terrell
# Processing Record 2 of Set 6 | geraldton
# Processing Record 3 of Set 6 | haines junction
# Processing Record 4 of Set 6 | kosh-agach
# Processing Record 5 of Set 6 | mantua
# Processing Record 6 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 6 | aleksandrovskiy zavod
# Processing Record 8 of Set 6 | marsa matruh
# Processing Record 9 of Set 6 | kulhudhuffushi
# Processing Record 10 of Set 6 | poya
# Processing Record 11 of Set 6 | emerald
# Processing Record 12 of Set 6 | smithers
# Processing Record 13 of Set 6 | yambio
# Processing Record 14 of Set 6 | adwa
# Processing Record 15 of Set 6 | constitucion
# Processing Record 16 of Set 6 | pedernales
# Processing Record 17 of Set 6 | avera
# Processing Record 18 of Set 6 | isangel
# Processing Record 19 of Set 6 | oranjemund
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | invercargill
# Processing Record 22 of Set 6 | uzumlu
# City not found. Skipping...
# Processing Record 23 of Set 6 | la palma
# Processing Record 24 of Set 6 | axim
# Processing Record 25 of Set 6 | chimbote
# Processing Record 26 of Set 6 | baykalovo
# Processing Record 27 of Set 6 | kapustin yar
# Processing Record 28 of Set 6 | zacualpan
# Processing Record 29 of Set 6 | charters towers
# Processing Record 30 of Set 6 | bethel
# Processing Record 31 of Set 6 | tasiilaq
# Processing Record 32 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 6 | apiai
# Processing Record 34 of Set 6 | huilong
# Processing Record 35 of Set 6 | chernyshevskiy
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | kudchi
# City not found. Skipping...
# Processing Record 38 of Set 6 | yilan
# Processing Record 39 of Set 6 | mayumba
# Processing Record 40 of Set 6 | serowe
# Processing Record 41 of Set 6 | samarai
# Processing Record 42 of Set 6 | guanica
# Processing Record 43 of Set 6 | svetlyy
# Processing Record 44 of Set 6 | imeni poliny osipenko
# Processing Record 45 of Set 6 | sharlyk
# Processing Record 46 of Set 6 | aykhal
# Processing Record 47 of Set 6 | katsuura
# Processing Record 48 of Set 6 | luderitz
# Processing Record 49 of Set 6 | talnakh
# Processing Record 50 of Set 6 | batagay-alyta
# Processing Record 1 of Set 7 | georgetown
# Processing Record 2 of Set 7 | ketrzyn
# Processing Record 3 of Set 7 | borama
# City not found. Skipping...
# Processing Record 4 of Set 7 | ulladulla
# Processing Record 5 of Set 7 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 6 of Set 7 | monforte de lemos
# Processing Record 7 of Set 7 | tukrah
# Processing Record 8 of Set 7 | luwuk
# Processing Record 9 of Set 7 | meadow lake
# Processing Record 10 of Set 7 | comodoro rivadavia
# Processing Record 11 of Set 7 | okhotsk
# Processing Record 12 of Set 7 | nhulunbuy
# Processing Record 13 of Set 7 | gamba
# Processing Record 14 of Set 7 | serik
# Processing Record 15 of Set 7 | alice springs
# Processing Record 16 of Set 7 | jasper
# Processing Record 17 of Set 7 | lasa
# Processing Record 18 of Set 7 | dharchula
# Processing Record 19 of Set 7 | srednekolymsk
# Processing Record 20 of Set 7 | la ronge
# Processing Record 21 of Set 7 | winsum
# Processing Record 22 of Set 7 | mandera
# Processing Record 23 of Set 7 | gorin
# Processing Record 24 of Set 7 | wenling
# Processing Record 25 of Set 7 | port lincoln
# Processing Record 26 of Set 7 | miles city
# Processing Record 27 of Set 7 | hamilton
# Processing Record 28 of Set 7 | jacareacanga
# Processing Record 29 of Set 7 | peniche
# Processing Record 30 of Set 7 | kentau
# Processing Record 31 of Set 7 | rabo de peixe
# Processing Record 32 of Set 7 | sechura
# Processing Record 33 of Set 7 | port augusta
# Processing Record 34 of Set 7 | cordoba
# Processing Record 35 of Set 7 | vestmanna
# Processing Record 36 of Set 7 | north bend
# Processing Record 37 of Set 7 | singaraja
# Processing Record 38 of Set 7 | cayenne
# Processing Record 39 of Set 7 | port hedland
# Processing Record 40 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 7 | carauari
# Processing Record 42 of Set 7 | aklavik
# Processing Record 43 of Set 7 | najran
# Processing Record 44 of Set 7 | champerico
# Processing Record 45 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 46 of Set 7 | bhabua
# Processing Record 47 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 7 | pontalina
# Processing Record 49 of Set 7 | santa isabel do rio negro
# Processing Record 50 of Set 7 | beya
# Processing Record 1 of Set 8 | torbay
# Processing Record 2 of Set 8 | nizhniy tsasuchey
# Processing Record 3 of Set 8 | ancud
# Processing Record 4 of Set 8 | merauke
# Processing Record 5 of Set 8 | caloundra
# Processing Record 6 of Set 8 | cam ranh
# Processing Record 7 of Set 8 | konya
# Processing Record 8 of Set 8 | flinders
# Processing Record 9 of Set 8 | rudbar
# Processing Record 10 of Set 8 | taksimo
# Processing Record 11 of Set 8 | san patricio
# Processing Record 12 of Set 8 | noumea
# Processing Record 13 of Set 8 | lazarev
# Processing Record 14 of Set 8 | cotonou
# Processing Record 15 of Set 8 | touros
# Processing Record 16 of Set 8 | copiapo
# Processing Record 17 of Set 8 | lancaster
# Processing Record 18 of Set 8 | sibu
# Processing Record 19 of Set 8 | tocantinopolis
# City not found. Skipping...
# Processing Record 20 of Set 8 | guerrero negro
# Processing Record 21 of Set 8 | marshalltown
# Processing Record 22 of Set 8 | lillehammer
# Processing Record 23 of Set 8 | angoche
# Processing Record 24 of Set 8 | qaqortoq
# Processing Record 25 of Set 8 | muzhi
# Processing Record 26 of Set 8 | maniitsoq
# Processing Record 27 of Set 8 | chumphon
# Processing Record 28 of Set 8 | katobu
# Processing Record 29 of Set 8 | muros
# Processing Record 30 of Set 8 | si sa ket
# Processing Record 31 of Set 8 | albert
# Processing Record 32 of Set 8 | lagoa
# Processing Record 33 of Set 8 | nantucket
# Processing Record 34 of Set 8 | sitka
# Processing Record 35 of Set 8 | codrington
# Processing Record 36 of Set 8 | matay
# Processing Record 37 of Set 8 | lorengau
# Processing Record 38 of Set 8 | sangar
# Processing Record 39 of Set 8 | eten
# Processing Record 40 of Set 8 | orahovac
# Processing Record 41 of Set 8 | kavaratti
# Processing Record 42 of Set 8 | temple
# Processing Record 43 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 8 | vilyuysk
# Processing Record 46 of Set 8 | lodja
# Processing Record 47 of Set 8 | ribas do rio pardo
# Processing Record 48 of Set 8 | taitung
# Processing Record 49 of Set 8 | vostok
# Processing Record 50 of Set 8 | manzhouli
# Processing Record 1 of Set 9 | san ignacio
# Processing Record 2 of Set 9 | dudinka
# Processing Record 3 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 9 | matagami
# Processing Record 5 of Set 9 | krasnoselkup
# Processing Record 6 of Set 9 | tibati
# Processing Record 7 of Set 9 | quelimane
# Processing Record 8 of Set 9 | agadez
# Processing Record 9 of Set 9 | araripe
# Processing Record 10 of Set 9 | kolpny
# Processing Record 11 of Set 9 | ballyshannon
# Processing Record 12 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 9 | zhangjiakou
# Processing Record 14 of Set 9 | mtwara
# Processing Record 15 of Set 9 | mossendjo
# Processing Record 16 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 9 | berea
# Processing Record 18 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 19 of Set 9 | andenes
# Processing Record 20 of Set 9 | lata
# Processing Record 21 of Set 9 | abonnema
# Processing Record 22 of Set 9 | mizdah
# Processing Record 23 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 9 | mareeba
# Processing Record 26 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 9 | kot radha kishan
# Processing Record 28 of Set 9 | alofi
# Processing Record 29 of Set 9 | zhengjiatun
# Processing Record 30 of Set 9 | taltal
# Processing Record 31 of Set 9 | praia
# Processing Record 32 of Set 9 | belyy yar
# Processing Record 33 of Set 9 | colesberg
# Processing Record 34 of Set 9 | banikoara
# Processing Record 35 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 36 of Set 9 | harnosand
# Processing Record 37 of Set 9 | abu samrah
# Processing Record 38 of Set 9 | pergamino
# Processing Record 39 of Set 9 | fayetteville
# Processing Record 40 of Set 9 | piacabucu
# Processing Record 41 of Set 9 | paracale
# Processing Record 42 of Set 9 | ust-kuyga
# Processing Record 43 of Set 9 | gayny
# Processing Record 44 of Set 9 | sigli
# Processing Record 45 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 9 | saint-louis
# Processing Record 47 of Set 9 | bataipora
# Processing Record 48 of Set 9 | svetlogorsk
# Processing Record 49 of Set 9 | ajdabiya
# Processing Record 50 of Set 9 | banda aceh
# Processing Record 1 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 10 | sorland
# Processing Record 3 of Set 10 | mlonggo
# Processing Record 4 of Set 10 | rosetta
# Processing Record 5 of Set 10 | chittur
# Processing Record 6 of Set 10 | zhanaozen
# Processing Record 7 of Set 10 | cabedelo
# Processing Record 8 of Set 10 | leningradskiy
# Processing Record 9 of Set 10 | cairns
# Processing Record 10 of Set 10 | san quintin
# Processing Record 11 of Set 10 | tuatapere
# Processing Record 12 of Set 10 | burnie
# Processing Record 13 of Set 10 | port-gentil
# Processing Record 14 of Set 10 | olafsvik
# Processing Record 15 of Set 10 | beloha
# Processing Record 16 of Set 10 | mount pleasant
# Processing Record 17 of Set 10 | bodden town
# Processing Record 18 of Set 10 | palauig
# Processing Record 19 of Set 10 | havre-saint-pierre
# Processing Record 20 of Set 10 | sag
# Processing Record 21 of Set 10 | quzhou
# Processing Record 22 of Set 10 | loanda
# Processing Record 23 of Set 10 | dingzhou
# Processing Record 24 of Set 10 | forestville
# Processing Record 25 of Set 10 | havoysund
# Processing Record 26 of Set 10 | bandarbeyla
# Processing Record 27 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 10 | dolni dabnik
# Processing Record 29 of Set 10 | tongliao
# Processing Record 30 of Set 10 | tahoua
# Processing Record 31 of Set 10 | ochtrup
# Processing Record 32 of Set 10 | harper
# Processing Record 33 of Set 10 | awjilah
# Processing Record 34 of Set 10 | richards bay
# Processing Record 35 of Set 10 | iquitos
# Processing Record 36 of Set 10 | natchez
# Processing Record 37 of Set 10 | sistranda
# Processing Record 38 of Set 10 | zorritos
# Processing Record 39 of Set 10 | evensk
# Processing Record 40 of Set 10 | salalah
# Processing Record 41 of Set 10 | kyzyl-suu
# Processing Record 42 of Set 10 | langres
# Processing Record 43 of Set 10 | dubrovnik
# Processing Record 44 of Set 10 | walvis bay
# Processing Record 45 of Set 10 | gunjur
# Processing Record 46 of Set 10 | amahai
# Processing Record 47 of Set 10 | la rioja
# Processing Record 48 of Set 10 | mangrol
# Processing Record 49 of Set 10 | banjarmasin
# Processing Record 50 of Set 10 | bairiki
# Processing Record 1 of Set 11 | verkhnevilyuysk
# Processing Record 2 of Set 11 | ndjole
# Processing Record 3 of Set 11 | ibra
# Processing Record 4 of Set 11 | de-kastri
# Processing Record 5 of Set 11 | yar-sale
# Processing Record 6 of Set 11 | iquique
# Processing Record 7 of Set 11 | flores
# Processing Record 8 of Set 11 | hirara
# Processing Record 9 of Set 11 | kiunga
# Processing Record 10 of Set 11 | zalantun
# Processing Record 11 of Set 11 | boende
# Processing Record 12 of Set 11 | moses lake
# Processing Record 13 of Set 11 | skibbereen
# Processing Record 14 of Set 11 | tual
# Processing Record 15 of Set 11 | alexandria
# Processing Record 16 of Set 11 | bajil
# Processing Record 17 of Set 11 | bonga
# Processing Record 18 of Set 11 | turbat
# Processing Record 19 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 20 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 11 | dwarka
# Processing Record 22 of Set 11 | fuyang
# Processing Record 23 of Set 11 | bedford
# Processing Record 24 of Set 11 | algiers
# Processing Record 25 of Set 11 | atasu
# Processing Record 26 of Set 11 | anito
# Processing Record 27 of Set 11 | tabas
# Processing Record 28 of Set 11 | yaviza
# Processing Record 29 of Set 11 | umm lajj
# Processing Record 30 of Set 11 | whithorn
# Processing Record 31 of Set 11 | belen
# Processing Record 32 of Set 11 | impfondo
# Processing Record 33 of Set 11 | flin flon
# Processing Record 34 of Set 11 | kahama
# Processing Record 35 of Set 11 | mumford
# Processing Record 36 of Set 11 | lengshuijiang
# Processing Record 37 of Set 11 | salamiyah
# Processing Record 38 of Set 11 | arman
# Processing Record 39 of Set 11 | mitu
# Processing Record 40 of Set 11 | cherskiy
# Processing Record 41 of Set 11 | kishorganj
# Processing Record 42 of Set 11 | seoul
# Processing Record 43 of Set 11 | esperance
# Processing Record 44 of Set 11 | qasigiannguit
# Processing Record 45 of Set 11 | mount gambier
# Processing Record 46 of Set 11 | kaitangata
# Processing Record 47 of Set 11 | maneadero
# Processing Record 48 of Set 11 | santa maria
# Processing Record 49 of Set 11 | rio gallegos
# Processing Record 50 of Set 11 | garzon
# Processing Record 1 of Set 12 | santa cruz
# Processing Record 2 of Set 12 | karratha
# Processing Record 3 of Set 12 | mahon
# Processing Record 4 of Set 12 | luanda
# Processing Record 5 of Set 12 | launceston
# Processing Record 6 of Set 12 | nanakuli
# Processing Record 7 of Set 12 | mankapur
# Processing Record 8 of Set 12 | opatija
# Processing Record 9 of Set 12 | erzin
# Processing Record 10 of Set 12 | puerto del rosario
# Processing Record 11 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 12 | agirish
# Processing Record 13 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 12 | huarmey
# Processing Record 15 of Set 12 | southbridge
# Processing Record 16 of Set 12 | port pirie
# Processing Record 17 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 18 of Set 12 | olga
# Processing Record 19 of Set 12 | lumut
# Processing Record 20 of Set 12 | tupik
# Processing Record 21 of Set 12 | golyshmanovo
# Processing Record 22 of Set 12 | qianan
# Processing Record 23 of Set 12 | ahipara
# Processing Record 24 of Set 12 | izumo
# Processing Record 25 of Set 12 | mount isa
# Processing Record 26 of Set 12 | kouqian
# Processing Record 27 of Set 12 | iqaluit
# Processing Record 28 of Set 12 | nirgua
# Processing Record 29 of Set 12 | asau
# Processing Record 30 of Set 12 | tyret pervaya
# Processing Record 31 of Set 12 | mehamn
# Processing Record 32 of Set 12 | ngunguru
# Processing Record 33 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 12 | signagi
# City not found. Skipping...
# Processing Record 35 of Set 12 | viisoara
# Processing Record 36 of Set 12 | chilliwack
# Processing Record 37 of Set 12 | yerofey pavlovich
# Processing Record 38 of Set 12 | tiarei
# Processing Record 39 of Set 12 | joensuu
# Processing Record 40 of Set 12 | opuwo
# Processing Record 41 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 12 | san carlos de bariloche
# Processing Record 43 of Set 12 | jumla
# Processing Record 44 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 45 of Set 12 | taylor
# Processing Record 46 of Set 12 | panguna
# Processing Record 47 of Set 12 | cerkezkoy
# Processing Record 48 of Set 12 | chegdomyn
# Processing Record 49 of Set 12 | naryan-mar
# Processing Record 50 of Set 12 | shemordan
# Processing Record 1 of Set 13 | makaha
# Processing Record 2 of Set 13 | aasiaat
# Processing Record 3 of Set 13 | suntar
# Processing Record 4 of Set 13 | pangai
# Processing Record 5 of Set 13 | krasnaya gorka
# Processing Record 6 of Set 13 | rehoboth
# Processing Record 7 of Set 13 | namibe
# Processing Record 8 of Set 13 | cidreira
# Processing Record 9 of Set 13 | shingu
# Processing Record 10 of Set 13 | fasa
# Processing Record 11 of Set 13 | fare
# Processing Record 12 of Set 13 | anadyr
# Processing Record 13 of Set 13 | honningsvag
# Processing Record 14 of Set 13 | giulianova
# Processing Record 15 of Set 13 | celestun
# Processing Record 16 of Set 13 | astoria
# Processing Record 17 of Set 13 | myszkow
# Processing Record 18 of Set 13 | calbuco
# Processing Record 19 of Set 13 | semey
# Processing Record 20 of Set 13 | los llanos de aridane
# Processing Record 21 of Set 13 | bollnas
# Processing Record 22 of Set 13 | goderich
# Processing Record 23 of Set 13 | qingdao
# Processing Record 24 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 26 of Set 13 | mnogovershinnyy
# Processing Record 27 of Set 13 | sayyan
# Processing Record 28 of Set 13 | uren
# Processing Record 29 of Set 13 | wladyslawowo
# Processing Record 30 of Set 13 | acari
# Processing Record 31 of Set 13 | orange cove
# Processing Record 32 of Set 13 | gzhatsk
# City not found. Skipping...
# Processing Record 33 of Set 13 | gornopravdinsk
# Processing Record 34 of Set 13 | bolobo
# Processing Record 35 of Set 13 | limoeiro do ajuru
# Processing Record 36 of Set 13 | hambantota
# Processing Record 37 of Set 13 | ciledug
# City not found. Skipping...
# Processing Record 38 of Set 13 | rocha
# Processing Record 39 of Set 13 | shitkino
# Processing Record 40 of Set 13 | wajir
# Processing Record 41 of Set 13 | artvin
# Processing Record 42 of Set 13 | marawi
# Processing Record 43 of Set 13 | chapais
# Processing Record 44 of Set 13 | port blair
# Processing Record 45 of Set 13 | mutoko
# Processing Record 46 of Set 13 | abha
# Processing Record 47 of Set 13 | el vigia
# Processing Record 48 of Set 13 | ixtapa
# Processing Record 49 of Set 13 | shahr-e kord
# Processing Record 50 of Set 13 | udachnyy
# Processing Record 1 of Set 14 | poroshkovo
# Processing Record 2 of Set 14 | paragominas
# Processing Record 3 of Set 14 | broken hill
# Processing Record 4 of Set 14 | el monte
# Processing Record 5 of Set 14 | port said
# Processing Record 6 of Set 14 | grindavik
# Processing Record 7 of Set 14 | pierre
# Processing Record 8 of Set 14 | waingapu
# Processing Record 9 of Set 14 | bondoukou
# Processing Record 10 of Set 14 | saraland
# Processing Record 11 of Set 14 | hayato
# City not found. Skipping...
# Processing Record 12 of Set 14 | meulaboh
# Processing Record 13 of Set 14 | natal
# Processing Record 14 of Set 14 | luba
# Processing Record 15 of Set 14 | sivaki
# Processing Record 16 of Set 14 | balykshi
# Processing Record 17 of Set 14 | sal rei
# Processing Record 18 of Set 14 | traverse city
# Processing Record 19 of Set 14 | atar
# Processing Record 20 of Set 14 | saint-pierre
# Processing Record 21 of Set 14 | lazaro cardenas
# Processing Record 22 of Set 14 | breytovo
# Processing Record 23 of Set 14 | funadhoo
# Processing Record 24 of Set 14 | englewood
# Processing Record 25 of Set 14 | narodychi
# Processing Record 26 of Set 14 | kachug
# Processing Record 27 of Set 14 | ust-maya
# Processing Record 28 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 14 | kushmurun
# Processing Record 30 of Set 14 | lewisporte
# Processing Record 31 of Set 14 | perth
# Processing Record 32 of Set 14 | san miguelito
# Processing Record 33 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 14 | gladstone
# Processing Record 35 of Set 14 | monamon
# Processing Record 36 of Set 14 | carutapera
# Processing Record 37 of Set 14 | bouca
# Processing Record 38 of Set 14 | kurchum
# Processing Record 39 of Set 14 | cockburn town
# Processing Record 40 of Set 14 | zhanakorgan
# Processing Record 41 of Set 14 | belgrade
# Processing Record 42 of Set 14 | sao joao da barra
# Processing Record 43 of Set 14 | deputatskiy
# Processing Record 44 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 14 | kieta
# Processing Record 46 of Set 14 | sola
# Processing Record 47 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 14 | praya
# Processing Record 49 of Set 14 | tura
# Processing Record 50 of Set 14 | raudeberg
# Processing Record 1 of Set 15 | magadan
# Processing Record 2 of Set 15 | nadvoitsy
# Processing Record 3 of Set 15 | thurso
# Processing Record 4 of Set 15 | ventspils
# Processing Record 5 of Set 15 | pinahat
# Processing Record 6 of Set 15 | ossora
# Processing Record 7 of Set 15 | erenhot
# Processing Record 8 of Set 15 | benalla
# Processing Record 9 of Set 15 | havelock
# Processing Record 10 of Set 15 | santa helena
# Processing Record 11 of Set 15 | japura
# Processing Record 12 of Set 15 | ayolas
# Processing Record 13 of Set 15 | luziania
# Processing Record 14 of Set 15 | tomatlan
# Processing Record 15 of Set 15 | kihei
# Processing Record 16 of Set 15 | tamandare
# Processing Record 17 of Set 15 | tulun
# Processing Record 18 of Set 15 | lisakovsk
# Processing Record 19 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 20 of Set 15 | ambunti
# Processing Record 21 of Set 15 | zhicheng
# Processing Record 22 of Set 15 | myitkyina
# Processing Record 23 of Set 15 | oktyabrskiy
# Processing Record 24 of Set 15 | lichinga
# Processing Record 25 of Set 15 | progreso
# Processing Record 26 of Set 15 | jacqueville
# Processing Record 27 of Set 15 | jiwani
# Processing Record 28 of Set 15 | mackenzie
# Processing Record 29 of Set 15 | yaan
# Processing Record 30 of Set 15 | jalu
# Processing Record 31 of Set 15 | agde
# Processing Record 32 of Set 15 | laurel
# Processing Record 33 of Set 15 | kloulklubed
# Processing Record 34 of Set 15 | mabaruma
# Processing Record 35 of Set 15 | mogadishu
# Processing Record 36 of Set 15 | pirgos
# Processing Record 37 of Set 15 | zyryanka
# Processing Record 38 of Set 15 | bend
# Processing Record 39 of Set 15 | port macquarie
# Processing Record 40 of Set 15 | marzuq
# Processing Record 41 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 15 | tailai
# Processing Record 43 of Set 15 | kaeo
# Processing Record 44 of Set 15 | rundu
# Processing Record 45 of Set 15 | riosucio
# Processing Record 46 of Set 15 | mahanoro
# Processing Record 47 of Set 15 | mikuni
# Processing Record 48 of Set 15 | kokoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat      Lng Current Description  Max Temp  Humidity  \
# 0     Port Alfred -33.5906  26.8910     overcast clouds     69.80        88
# 1     Clyde River  70.4692 -68.5914     overcast clouds    -17.86        85
# 2      Concarneau  47.8750  -3.9225       broken clouds     49.05        83
# 3    Punta Arenas -53.1500 -70.9167          few clouds     62.71        34
# 4         Ushuaia -54.8000 -68.3000    scattered clouds     64.02        62
# 5           Forio  40.7342  13.8646       broken clouds     53.46        77
# 6  Saint-Philippe -21.3585  55.7679     overcast clouds     76.59        76
# 7       Cape Town -33.9258  18.4232           clear sky     70.21        64
# 8          Gornyy  55.1153  83.9059       broken clouds     -5.49       100
# 9         Sedhiou  12.7081 -15.5569     overcast clouds     82.09        15
#
#    Cloudiness  Wind Speed Country
# 0          98       18.68      ZA
# 1          94        5.35      CA
# 2          71       11.18      FR
# 3          20       32.21      CL
# 4          40       32.21      AR
# 5          60        1.99      IT
# 6         100        3.44      RE
# 7           0        5.99      ZA
# 8          68        3.15      RU
# 9          97        6.51      SN

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
